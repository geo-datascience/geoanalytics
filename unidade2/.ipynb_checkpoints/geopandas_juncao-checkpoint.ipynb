# %% [markdown]
# # Junção Espacial
#
# ## Função sJoin
#
# predicate = 'contains', 'crosses', 'intersects', 'within', 'touches', 'overlaps', None, 'covers', 'contains_properly'

# %%
# %matplotlib inline
import os
import conda
os.environ['USE_PYGEOS'] = '0'
conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

# %%
import geopandas as gpd

escolas_par = gpd.read_file("../dados/escola_particular.geojson")
regional = gpd.read_file("../dados/REGIONAL.shp")
regional_le = regional[regional['SIGLA']=='LE']
escolas_par_le = gpd.sjoin(escolas_par, regional_le)

# %%
basemap = regional_le.boundary.plot(color='k', figsize=(10, 10))
escolas_par_le.plot(ax=basemap, color='red' )
# Out:
# <Axes: >
