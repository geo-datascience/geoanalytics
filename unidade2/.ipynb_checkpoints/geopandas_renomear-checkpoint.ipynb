# %% [markdown]
# # Modificando o GeoDataFrame

# %%
# %matplotlib inline
import os
import conda
os.environ['USE_PYGEOS'] = '0'
conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

# %%
import geopandas as gpd

imoveis = gpd.read_file("../dados/house_bh.csv")
imoveis
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
#                                  address adm-fees garage-places      price  \
# 0           Avenida Raja Gabaglia, 1583     470.0             1   330000.0
# 1              Rua Espírito Santo, 1171                       1   480000.0
# 2         Rua dos Expedicionários, 1082                       5  1190000.0
# 3               Rua Marechal Hermes, 81     750.0             4  1590000.0
# 4                       Rua Juruna, 110                       6   550000.0
# ...                                  ...      ...           ...        ...
# 5976                 Rua Gama Cerqueira     340.0             2   560000.0
# 5977           Rua Arthur Lourenço, 262     200.0             1   440000.0
# 5978  Rua General Ephigênio Ruas Santos      10.0             2   500000.0
# 5979  Rua General Ephigênio Ruas Santos      10.0             2   740000.0
# ...

# %%
imoveis.columns
# Out:
# Index(['address', 'adm-fees', 'garage-places', 'price', 'rooms', 'square-foot',
#        'neighborhood', 'city', 'latitude', 'longitude', 'geometry'],
#       dtype='object')

# %%
imoveis.columns = ['endereco', 'condominio', 'vagas-garagem', 'preco', 'quartos', 'tamanho','bairro', 'cidade', 'latitude', 'longitude', 'geometry']

# %%
imoveis.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5981 entries, 0 to 5980
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   endereco       5981 non-null   object
#  1   condominio     5981 non-null   object
#  2   vagas-garagem  5981 non-null   object
#  3   preco          5981 non-null   object
#  4   quartos        5981 non-null   object
#  5   tamanho        5981 non-null   object
#  6   bairro         5981 non-null   object
#  7   cidade         5981 non-null   object
#  8   latitude       5981 non-null   object
#  9   longitude      5981 non-null   object
#  10  geometry       0 non-null      geometry
# dtypes: geometry(1), object(10)
# memory usage: 514.1+ KB

# %%
imoveis = gpd.read_file("data/house_bh.csv")
imoveis
# Out:
#                                  address adm-fees garage-places      price  \
# 0           Avenida Raja Gabaglia, 1583     470.0             1   330000.0
# 1              Rua Espírito Santo, 1171                       1   480000.0
# 2         Rua dos Expedicionários, 1082                       5  1190000.0
# 3               Rua Marechal Hermes, 81     750.0             4  1590000.0
# 4                       Rua Juruna, 110                       6   550000.0
# ...                                  ...      ...           ...        ...
# 5976                 Rua Gama Cerqueira     340.0             2   560000.0
# 5977           Rua Arthur Lourenço, 262     200.0             1   440000.0
# 5978  Rua General Ephigênio Ruas Santos      10.0             2   500000.0
# 5979  Rua General Ephigênio Ruas Santos      10.0             2   740000.0
# 5980                Avenida do Contorno                       3  4990000.0
#
# ...

# %%
imoveis.rename(columns={"garage-places":"vagas-garagem", "neighborhood":"bairro", "city":"cidade"})
imoveis.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5981 entries, 0 to 5980
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   address        5981 non-null   object
#  1   adm-fees       5981 non-null   object
#  2   garage-places  5981 non-null   object
#  3   price          5981 non-null   object
#  4   rooms          5981 non-null   object
#  5   square-foot    5981 non-null   object
#  6   neighborhood   5981 non-null   object
#  7   city           5981 non-null   object
#  8   latitude       5981 non-null   object
#  9   longitude      5981 non-null   object
#  10  geometry       0 non-null      geometry
# dtypes: geometry(1), object(10)
# memory usage: 514.1+ KB

# %% [markdown]
# And nothing seemed to happen, why?  With this method we need to set the inplace parameter to True in order to persist the change to the GeoDataFrame beyond the immediate command.

# %%
imoveis.rename(inplace=True, columns={"garage-places":"vagas-garagem", "neighborhood":"bairro", "city":"cidade"})
imoveis.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5981 entries, 0 to 5980
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   address        5981 non-null   object
#  1   adm-fees       5981 non-null   object
#  2   vagas-garagem  5981 non-null   object
#  3   price          5981 non-null   object
#  4   rooms          5981 non-null   object
#  5   square-foot    5981 non-null   object
#  6   bairro         5981 non-null   object
#  7   cidade         5981 non-null   object
#  8   latitude       5981 non-null   object
#  9   longitude      5981 non-null   object
#  10  geometry       0 non-null      geometry
# dtypes: geometry(1), object(10)
# memory usage: 514.1+ KB

# %%
imoveis.add_suffix("_old")
# Out:
#                              address_old adm-fees_old vagas-garagem_old  \
# 0           Avenida Raja Gabaglia, 1583         470.0                 1
# 1              Rua Espírito Santo, 1171                               1
# 2         Rua dos Expedicionários, 1082                               5
# 3               Rua Marechal Hermes, 81         750.0                 4
# 4                       Rua Juruna, 110                               6
# ...                                  ...          ...               ...
# 5976                 Rua Gama Cerqueira         340.0                 2
# 5977           Rua Arthur Lourenço, 262         200.0                 1
# 5978  Rua General Ephigênio Ruas Santos          10.0                 2
# 5979  Rua General Ephigênio Ruas Santos          10.0                 2
# 5980                Avenida do Contorno                               3
#
#       price_old rooms_old square-foot_old     bairro_old        cidade_old  \
# ...
