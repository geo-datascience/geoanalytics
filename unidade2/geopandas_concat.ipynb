# %% [markdown]
# # Concatenando Dados
#
# ## Função Concat

# %%
# %matplotlib inline
import os
import conda
os.environ['USE_PYGEOS'] = '0'
conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

# %%
import geopandas as gpd

escolas_mun = gpd.read_file("../dados/escola_municipal.geojson")
escolas_par = gpd.read_file("../dados/escola_particular.geojson")

# %%
escolas_mun.count()
# Out:
# id                   178
# ID_EQUIP_EDUCACAO    178
# NOME                 178
# DEPENDENCIA_ADM      178
# CODIGO_INEP          178
# TIPO_LOGRADOURO      178
# LOGRADOURO           178
# NUMERO               178
# COMPLEMENTO            0
# BAIRRO               178
# REGIONAL             178
# geometry             178
# dtype: int64

# %%
escolas_par.count()
# Out:
# id                   739
# ID_EQUIP_EDUCACAO    739
# NOME                 739
# DEPENDENCIA_ADM      739
# CODIGO_INEP          739
# TIPO_LOGRADOURO      739
# LOGRADOURO           739
# NUMERO               739
# COMPLEMENTO            0
# BAIRRO               739
# REGIONAL             739
# geometry             739
# dtype: int64

# %%
import pandas as pd

escolas = pd.concat([escolas_mun, escolas_par])
escolas.count()
# Out:
# id                   917
# ID_EQUIP_EDUCACAO    917
# NOME                 917
# DEPENDENCIA_ADM      917
# CODIGO_INEP          917
# TIPO_LOGRADOURO      917
# LOGRADOURO           917
# NUMERO               917
# COMPLEMENTO            0
# BAIRRO               917
# REGIONAL             917
# geometry             917
# dtype: int64

# %%
escolas
# Out:
#                                                 id  ID_EQUIP_EDUCACAO  \
# 0    ESCOLAS_MUNICIPAIS_ENSINO_FUNDAMENTAL.1981911            1981911
# 1    ESCOLAS_MUNICIPAIS_ENSINO_FUNDAMENTAL.1981851            1981851
# 2    ESCOLAS_MUNICIPAIS_ENSINO_FUNDAMENTAL.1981958            1981958
# 3    ESCOLAS_MUNICIPAIS_ENSINO_FUNDAMENTAL.1981876            1981876
# 4    ESCOLAS_MUNICIPAIS_ENSINO_FUNDAMENTAL.1981737            1981737
# ..                                             ...                ...
# 734                   ESCOLAS_PARTICULARES.1982894            1982894
# 735                   ESCOLAS_PARTICULARES.1982454            1982454
# 736                   ESCOLAS_PARTICULARES.1982744            1982744
# 737                   ESCOLAS_PARTICULARES.1982561            1982561
# 738                   ESCOLAS_PARTICULARES.1982996            1982996
#
#                                                   NOME DEPENDENCIA_ADM  \
# 0                      ESCOLA MUNICIPAL BELO HORIZONTE       Municipal
# 1                     ESCOLA MUNICIPAL FRANCISCA ALVES       Municipal
# 2                     ESCOLA MUNICIPAL ANISIO TEIXEIRA       Municipal
# 3                   ESCOLA MUNICIPAL ULYSSES GUIMARAES       Municipal
# 4                   ESCOLA MUNICIPAL DULCE MARIA HOMEM       Municipal
# ..                                                 ...             ...
# 734                        INST PSICOPEDAG ERA UMA VEZ      Particular
# 735                                   INST LA FONTAINE      Particular
# 736                   ESCOLA INFANTIL JARDIM ENCANTADO      Particular
# 737                         NUCLEO EDUCACIONAL PIU PIU      Particular
# 738  SENAI CENTRO DE FORMAÇÃO PROFISSIONAL EUVALDO ...      Particular
#
#     CODIGO_INEP TIPO_LOGRADOURO              LOGRADOURO  NUMERO COMPLEMENTO  \
# 0      31002593         AVENIDA          JOSE BONIFACIO     189        None
# 1      31002682         AVENIDA         SANTA TEREZINHA       8        None
# 2      31250651             RUA                 BOLIVAR      10        None
# 3      31231983             RUA                 BOLIVIA     532        None
# 4      31212776             RUA             TRES MARIAS     221        None
# ..          ...             ...                     ...     ...         ...
# 734    31332356             RUA           MONTES CLAROS     338        None
# 735    31007218             RUA           MONTES CLAROS    1300        None
# 736    31332178             RUA  ANTONIO MARCAL SAMPAIO     540        None
# 737    31348007             RUA   ALZIRA MARIA FERREIRA       6        None
# 738    31267767         AVENIDA         OLINTO MEIRELES      65        None
#
#                       BAIRRO    REGIONAL                        geometry
# 0              São Cristóvão    NOROESTE  POINT (610175.909 7798851.507)
# 1             Conjunto Lagoa    PAMPULHA  POINT (605029.389 7802820.210)
# 2                      União    NORDESTE  POINT (612440.267 7801048.000)
# 3       Santa Rita de Cássia  CENTRO-SUL  POINT (610930.997 7793592.238)
# 4                    Miramar    BARREIRO  POINT (603275.984 7788781.407)
# ..                       ...         ...                             ...
# 734                    Carmo  CENTRO-SUL  POINT (611726.795 7794337.056)
# 735                 Anchieta  CENTRO-SUL  POINT (612510.249 7793738.818)
# 736              Mantiqueira  VENDA NOVA  POINT (606120.075 7810374.042)
# 737             Santa Mônica  VENDA NOVA  POINT (607115.117 7807314.685)
# 738  Bairro das Indústrias I    BARREIRO  POINT (603104.108 7791293.006)
#
# [917 rows x 12 columns]
